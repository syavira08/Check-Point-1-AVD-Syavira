# %% [markdown]
# # **Sociolla: All Brands Products Catalog**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Memuat Dataset**

# %% [markdown]
# Dataset ini mencakup informasi tentang lebih dari 7.500 produk skincare dan make up yang diambil dari Sociolla. Tujuan dari dataset ini adalah untuk memberikan gambaran yang cukup luas tentang variasi brand, tingkat ketertarikan pengguna, serta aktivitas pasar di dunia kecantikan.

# %%
file = "/content/drive/MyDrive/Praktikum AVD/products_all_brands.csv"
df = pd.read_csv(file)
df
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher  Soin Stimulating Conditioner       64174
# 7633  273_yves-rocher              Repair Hair Mask       36357
# 7634  273_yves-rocher   Hand Cream Olive Petitgrain       36404
# 7635  273_yves-rocher                    Color Mask       64153
#
#       beauty_point_earned              price_range price_by_combinations  \
# 0                     130  Rp 555.000 - Rp 687.000                   NaN
# ...

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# Dataset Sociolla: All Brands Products Catalog
#
# Dataset ini mencakup informasi tentang lebih dari 7.500 produk skincare dan make up yang diambil dari Sociolla. Dengan banyaknya produk dari lebih dari 300 merek, dataset ini memberikan gambaran yang cukup luas tentang variasi brand, tingkat ketertarikan pengguna, serta aktivitas pasar di dunia kecantikan.
#
# Tujuan dari analisis ini adalah untuk memahami brand skincare atau make up mana yang terlihat lebih populer dan lebih banyak menarik perhatian pengguna. Popularitas ini dapat dilihat dari beberapa indikator, seperti jumlah rating, jumlah wishlist, dan bentuk interaksi pengguna lainnya yang tersedia di dataset. Dengan mengetahui brand mana yang paling menonjol, suatu bisnis dapat memahami tren pasar, melihat preferensi konsumen, dan mengetahui brand mana yang memiliki potensi kerja sama lebih besar.

# %% [markdown]
# ## **Asses Situation**

# %% [markdown]
# Situasi dalam dataset ini adalah terdapat begitu banyak informasi mengenai berbagai produk skincare dan make up dari banyak brand yang dijual secara online. Setiap brand memiliki tingkat perhatian pengguna yang berbeda-beda, misalnya ada yang banyak mendapat review, wishlist, atau penilaian, sementara ada juga brand yang hampir tidak memiliki interaksi sama sekali. Karena perbedaan ini, kita tidak bisa langsung menilai brand mana yang sebenarnya paling populer hanya dengan melihat datanya secara sekilas.
#
# Oleh karena itu, proses analisis tidak bisa dilakukan secara langsung. Kita perlu memeriksa, mengolah, dan menyiapkan datanya terlebih dahulu, supaya hasil analisis nanti bisa lebih akurat dan memberikan gambaran yang jelas tentang brand mana yang paling menarik perhatian pengguna.

# %% [markdown]
# ## **Analytic Goals & Project Plan**

# %% [markdown]
# Dalam dataset ini akan dilakukan:
# *   Menganalisis brand skincare mana yang terlihat lebih populer berdasarkan data seperti rating, wishlist, dan lain-lain.
# *   Melihat pola ketertarikan pengguna terhadap produk dari tiap brand.
# *   Membuat visualisasi agar hasil analisis mudah dipahami.
# *   Menyediakan dasar untuk membantu pengambilan keputusan terkait brand mana yang paling menarik bagi pengguna.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7636 entries, 0 to 7635
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   brand_name                    7636 non-null   object
#  1   product_name                  7636 non-null   object
#  2   product_id                    7636 non-null   int64
#  3   beauty_point_earned           7636 non-null   int64
#  4   price_range                   7636 non-null   object
#  5   price_by_combinations         4087 non-null   object
#  6   url                           7636 non-null   object
#  7   active_date                   5534 non-null   object
#  8   default_category              7636 non-null   object
#  9   categories                    7632 non-null   object
#  10  rating_types_str              7561 non-null   object
#  11  average_rating                7636 non-null   float64
# ...

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 7636 Baris dan 19 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7636 entries, 0 to 7635
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   brand_name                    7636 non-null   object
#  1   product_name                  7636 non-null   object
#  2   product_id                    7636 non-null   int64
#  3   beauty_point_earned           7636 non-null   int64
#  4   price_range                   7636 non-null   object
#  5   price_by_combinations         4087 non-null   object
#  6   url                           7636 non-null   object
#  7   active_date                   5534 non-null   object
#  8   default_category              7636 non-null   object
#  9   categories                    7632 non-null   object
#  10  rating_types_str              7561 non-null   object
#  11  average_rating                7636 non-null   float64
# ...

# %% [markdown]
# Dari data yang ditampilkan dapat diketahui hal-hal sebagai berikut:
# 1. **brand_name:** Jumlah baris: 7.636, Tipe data: object, Deskripsi: Nama Brand
# 2. **product_name:** Jumlah baris: 7.636, Tipe data: object, Deskripsi: Nama Produk
# 3. **product_id:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: ID Produk
# 4. **beauty_point_earned:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Jumlah beauty points yang bisa didapatkan pembeli
# 5. **price_range:** Jumlah baris: 7.636, Tipe data: object, Deskripsi: Rentang Harga
# 6. **price_by_combinations:** Jumlah baris: 4.087, Tipe data: object, Deskripsi: Harga Spesifik Berdasarkan Variasi Produk Yang Berbeda.
# 7. **url:** Jumlah baris: 7.636, Tipe data: object, Deskripsi: Tautan URL ke Setiap Produk di Sociolla.com
# 8. **active_date:** Jumlah baris: 5.534, Tipe data: object, Deskripsi: Tanggal produk tersedia di Sociolla.com
# 9. **default_category:** Jumlah baris: 7.636, Tipe data: object, Deskripsi: Kategori Default Produk
# 10. **categories:** Jumlah baris: 7.632, Tipe data: object, Deskripsi: Kategori Tambahan Untuk Klasifikasi Produk Yang Lebih Detail
# 11. **rating_types_str:** Jumlah baris: 7.561, Tipe data: object, Deskripsi: Rating Berdasarkan Jenis
# 12. **average_rating:** Jumlah baris: 7.636, Tipe data: float64, Deskripsi: Rating Rata-Rata Keseluruhan
# 13. **total_reviews:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Total Ulasan
# 14. **average_rating_by_types:** Jumlah baris: 5.790, Tipe data: object, Deskripsi: Rating Rata-Rata Untuk Jenis Tertentu
# 15. **total_recommended_count:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Total Rekomendasi dari Pelanggan
# 16. **total_repurchase_maybe_count:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Total Pelanggan Yang Mungkin Akan Beli Ulang Produk
# 17. **total_repurchase_no_count:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Total Pelanggan Yang Tidak Akan Beli Ulang Produk
# 18. **total_repurchase_yes_count:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Total Pelanggan Yang Akan Beli Ulang Produk
# 19. **total_in_wishlist:** Jumlah baris: 7.636, Tipe data: int64, Deskripsi: Total Pelanggan Yang Menambahkan Produk ke Wishlist

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        brand_name                                     product_name  \
# count        7636                                             7636
# unique        321                                             7576
# top     246_nivea  Tips to Keep Your Skin Healthy While Travelling
# freq          160                                                3
# mean          NaN                                              NaN
# std           NaN                                              NaN
# min           NaN                                              NaN
# 25%           NaN                                              NaN
# 50%           NaN                                              NaN
# 75%           NaN                                              NaN
# max           NaN                                              NaN
#
#            product_id  beauty_point_earned price_range price_by_combinations  \
# count     7636.000000          7636.000000        7636                  4087
# ...

# %% [markdown]
# 1. **Count** (Kelengkapan Data) Berdasarkan jumlah baris = 7.636, maka dapat disimpulkan:
# *   Kolom **price_by_combinations** hilang 3.549 data (7.636 - 4.087)
# *   Kolom **active_date** hilang 2.102 data (7.636 - 5.534)
# *   Kolom **categories** hilang 4 data (7.636 - 7.632)
# *   Kolom **rating_types_str** hilang 75 data (7.636 - 7.561)
# *   Kolom **average_rating_by_types** hilang 1.846 data (7.636 - 5.790)
#
#
# Kesimpulan: Kolom yang disebutkan di atas mengandung missing values, sementara kolom lainnya sudah lengkap (7.636 data)
#
#
#
# ---
#
#
#
# 2. **Mean vs Median** (Distribusi Data) Berdasarkand data, berikut statistik numerik utama:
# *   Kolom **average_rating**
#     * Mean = 3,51
#     * Median = 4,57
#
#     Nilai median lebih tinggi, itu artinya banyak produk punya rating tinggi dan sedikit yang punya rating rendah.
#
# *   Kolom **total_reviews**
#     * Mean = 198,19
#     * Median = 9,00
#
#     Nilai mean jauh lebih besar, itu artinya ada produk dengan review sangat tinggi dan kemungkinan outlier.
#
# *   Kolom **total_recommended_count**
#     * Mean = 186,56
#     * Median = 9,00
#
#     Hanya sedikit produk yang direkomendasikan dalam jumlah sangat besar
#
# *   Kolom **total_in_wishlist**
#     * Mean = 633,01
#     * Median = 132.00
#
#     Perbedaan nilai yang besar antara mean dan median menunjukkan adanya produk dengan wishlist sangat tinggi.
#
# Kesimpulan: Data rating relatif stabil, tetapi untuk data pada kolom reviews, wishlist dan recommendation ini kebanyakan rendah, tapi ada beberapa angka yang sangat tinggi sehingga menarik rata-ratanya naik.
#
#
#
# ---
#
#
# 3. **Min dan Max** (Validasi Logika)
# *   Kolom **average_rating**
#     * Min = 0
#     * Max = 5
#
# *   Kolom **total_reviews**
#     * Min = 0
#     * Max = 21.536,00
#
# *   Kolom **total_recommended_count**
#     * Min = 0
#     * Max = 20.804,00
#
# *   Kolom **total_in_wishlist**
#     * Min = -317.00
#     * Max = 58.568,00
#
# Kesimpulan:
# *   Semua nilai masuk akal untuk platform besar.
# *   Rentang wishlist sangat lebar, menandakan gap popularitas antar produk cukup ekstrem.
#
#
#
# ---
#
#
#
# 4. **Standar Deviasi (std)** - Variabilitas Data
# *   **average_rating**
#     * Mean = 3,51
#     * Std = 2,00
#
#     Kesimpulan: Rating cukup stabil, mayoritas berada di range 4–5.
#
# *   **total_reviews**
#     * Mean = 198,19
#     * Std = 852,06
#
#     Kesimpulan: Variasi sangat tinggi (lebih dari 3x mean), artinya distribution sangat tidak merata.
#
# *   **total_recommended_count**
#     * Mean = 186,56
#     * Std = 803,18
#
#     Kesimpulan: Angka rekomendasi berbeda jauh antar produk, beberapa direkomendasikan ratusan kali dan mayoritas hanya sedikit.
#
# *   **total_in_wishlist**
#     * Mean = 633,01
#     * Std = 2.055,06
#
#     Kesimpulan: Variasi ekstrem, ada banyak produk kurang populer dan beberapa sangat populer.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Dari pengecekan data di bawah ini dapat dilihat bahwa pada kolom active_date dengan tipe data object, yang dimana seharusnya kolom ini bertipe data datetime bukan object. Selain itu, semua kolom sudah sesuai.

# %%
df.dtypes
# Out:
# brand_name                       object
# product_name                     object
# product_id                        int64
# beauty_point_earned               int64
# price_range                      object
# price_by_combinations            object
# url                              object
# active_date                      object
# default_category                 object
# categories                       object
# rating_types_str                 object
# average_rating                  float64
# total_reviews                     int64
# average_rating_by_types          object
# total_recommended_count           int64
# total_repurchase_maybe_count      int64
# total_repurchase_no_count         int64
# total_repurchase_yes_count        int64
# total_in_wishlist                 int64
# dtype: object

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# Dari pengecekan pada kolom categories di bawah ini dapat dilihat bahwa terdapat pencampuran bahasa dalam pengategorian produk, salah satunya yang sering muncul adalah bahasa Vietnam.

# %%
print(df['categories'].unique())
# Out:
# ['Makeup; Eyes; Eyeshadow' 'Makeup; Lips; Lip Cream'
#  'Makeup; Lips; Lipstick' 'Makeup; Face; Blush' 'Makeup; Lips; Lip Tint'
#  'Makeup; Eyes; Eyebrows' 'Makeup; Face; Foundation'
#  'Makeup; Eyes; Mascara' 'Makeup; Face; Pressed Powder'
#  'Makeup; Eyes; Eyeliner' 'Skincare; Treatment; Essence'
#  'Skincare; Sun Care; Sunscreen' 'Skincare; Skin Care Set'
#  'Skincare; Treatment; Toner' 'Skincare; Face Mask; Sheet Mask'
#  'Skincare; Moisturizer; Face Cream & Lotion'
#  'Skincare; Cleanser; Face Wash' 'Skincare; Face Mask; Wash off Mask'
#  'Skincare; Lip Care; Lip Balm' 'Skincare'
#  'Skincare; Cleanser; Cleansing Bar' 'Skincare; Cleanser; Cleansing Gel'
#  'Skincare; Treatment; Face Serum'
#  'Skincare; Skin Care Set; Skin Care Set' 'Skincare; Eye Care; Eye Cream'
#  'Skincare; Treatment; Ampoule' 'Skincare; Moisturizer; Face Oil'
#  'Skincare; Moisturizer; Face Gel'
#  'Skincare; Treatment; Acne Treatment / Sealing gel / Cream'
#  'Makeup; Face; Concealer'
# ...

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Pada tahap ini kita bisa melihat presentase data yang hilang di setiap kolom. Terlihat bahwa beberapa kolom memiliki nilai yang kosong, kolom tersebut antara lain:
# *   **price_by_combinations**
#
#     Memiliki missing values sekitar 46%, banyak data yang hilang menunjukkan bahwa tidak semua produk memiliki variasi harga berdasarkan kombinasi. Sehingga perlu ditangani atau dihapus.
#
# *   **active_date**
#
#     Memiliki missing values sekitar 27%, hal ini menunjukkan bahwa sebagian data tidak memiliki informasi kapan produk mulai aktif. Sehingga perlu ditangani atau dihapus.
#
# *   **categories**
#
#     Memiliki missing values sekitar 0,05%, jumlah missing sangat kecil. Hal ini menunjukkan bahwa hampir semua produk memiliki kategori yang jelas.
#
# *   **rating_types_str**
#
#     Memiliki missing values sekitar 0,98%, hal ini menunjukkan bahwa tidak semua produk memiliki detail tipe rating.
#
# *   **average_rating_by_types**
#
#     Memiliki missing values sekitar 24%, sekitar seperempat produk tidak memiliki rata-rata rating per tipe/varian, biasanya terjadi pada produk yang hanya punya satu tipe atau produk dengan jumlah ulasan sangat sedikit. Sehingga perlu ditangani atau dihapus.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                               Null Ratio in %
# brand_name                           0.000000
# product_name                         0.000000
# product_id                           0.000000
# beauty_point_earned                  0.000000
# price_range                          0.000000
# price_by_combinations               46.477213
# url                                  0.000000
# active_date                         27.527501
# default_category                     0.000000
# categories                           0.052383
# rating_types_str                     0.982190
# average_rating                       0.000000
# total_reviews                        0.000000
# average_rating_by_types             24.174961
# total_recommended_count              0.000000
# total_repurchase_maybe_count         0.000000
# total_repurchase_no_count            0.000000
# total_repurchase_yes_count           0.000000
# total_in_wishlist                    0.000000

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Dalam pengecekan duplikasi di bawah ini, terlihat bahwa pada dataset ini tidak ada duplikasi, maka hal ini tidak perlu ditangani.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [brand_name, product_name, product_id, beauty_point_earned, price_range, price_by_combinations, url, active_date, default_category, categories, rating_types_str, average_rating, total_reviews, average_rating_by_types, total_recommended_count, total_repurchase_maybe_count, total_repurchase_no_count, total_repurchase_yes_count, total_in_wishlist]
# Index: []

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Dari hasil pengecekan nilai ekstrem (outlier) pada kolom bertipe numerik berikut, dapat terlihat kolom:
# *   **product_id**
#
#     Dengan presentase sekitar 12%
#
# *   **beauty_point_earned**
#
#     Dengan presentase sekitar 4%
#
# *   **average_rating**
#
#     Dengan presentase sekitar 24%
#
# *   **total_reviews**
#
#     Dengan presentase sekitar 15%
#
# *   **total_recommended_count**
#
#     Dengan presentase sekitar 15%
#
# *   **total_repurchase_maybe_count**
#
#     Dengan presentase sekitar 15%
#
# *   **total_repurchase_no_count**
#
#     Dengan presentase sekitar 14%
#
# *   **total_repurchase_yes_count**
#
#     Dengan presentase sekitar 15%
#
# *   **total_in_wishlist**
#
#     Dengan presentase sekitar 11%

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                         Persentase Outliers
# product_id                              12.414877
# beauty_point_earned                      4.740702
# average_rating                          24.292823
# total_reviews                           15.675746
# total_recommended_count                 15.610267
# total_repurchase_maybe_count            15.217391
# total_repurchase_no_count               14.575694
# total_repurchase_yes_count              15.374542
# total_in_wishlist                       11.825563

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas: Membandingkan brand (brand_name) dengan total review dari pelanggan (total_reviews).
#
# Tujuan: Untuk mengetahui 10 brand teratas yang paling populer.
#
# Visualisasi: Bar Chart (Grafik Batang).

# %%
popular_brand = df.groupby('brand_name')['total_reviews'].sum().sort_values(ascending=False)

top_brand = popular_brand.head(10)

plt.figure(figsize=(10,6))
sns.barplot(
    x=top_brand.index,
    y=top_brand.values,
    palette='viridis',
    hue=top_brand.index,
    legend=False
)

plt.title('Top 10 Brand Paling Populer Berdasarkan Total Reviews')
plt.xlabel('Brand')
plt.ylabel('Total Reviews')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Dari hasil visualisasi tersebut, terdapat beberapa hal yang bisa disimpulkan yaitu antara lain:
#
# 1.   COSRX menjadi brand paling populer
#
#      * COSRX menempati posisi pertama dengan total review tertinggi, menunjukkan bahwa produk mereka sangat banyak digunakan dan aktif diulas oleh pelanggan.
#
# 2.   Emina dan Wardah juga memiliki popularitas yang sangat tinggi
#
#       * Emina dan Wardah berada di posisi kedua dan ketiga.
#       * Tingginya review menunjukkan bahwa kedua brand lokal ini memiliki basis pengguna besar dan tingkat interaksi yang tinggi di platform Sociolla.
#
# 3. Garnier dan Avoskin menyusul di posisi tengah
#
#     * Garnier menunjukkan konsistensi sebagai brand global yang populer.
#     * Avoskin mencerminkan pertumbuhan brand lokal dengan jumlah review yang cukup tinggi.
#
# 4. Brand lain seperti Nivea, Maybelline, Skintific, L'Oreal Paris, dan NPure berada di cluster populer namun tidak seintens top 3
#
#     * Mereka masih memiliki jumlah review besar, namun selisihnya cukup jauh dari COSRX, Emina, dan Wardah.
#     * Ini dapat menandakan bahwa produk mereka populer di kategori tertentu, tetapi tidak seluas brand teratas.

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas: Melihat presentase total rekomendasi pelanggan (total_recommended_count) berdasarkan kategori produk (default_category).
#
# Tujuan: Untuk mengetahui kategori produk mana yang paling direkomendasikan oleh para pelanggan Sociolla.
#
# Visualisasi: Pie Chart (Grafik Lingkaran).

# %%
composition_category = df.groupby('default_category')['total_recommended_count'].sum().sort_values(ascending=False)
composition_category_top5 = composition_category.head(5)

plt.figure(figsize=(10, 8))
composition_category_top5.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Komposisi 5 Kategori Teratas Berdasarkan Total Rekomendasi Pelanggan')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Dari hasil visualisasi tersebut, terdapat beberapa hal yang bisa disimpulkan yaitu antara lain:
#
# 1. Toner menjadi kategori yang paling banyak direkomendasikan (22.4%)
#
#     Ini menunjukkan bahwa toner adalah kategori yang paling populer atau paling dipercaya oleh konsumen.
#
# 2. Face Wash dan Sheet Mask juga memiliki tingkat rekomendasi tinggi (20–21%)
#
#     Kedua kategori ini berada pada posisi menengah dan memiliki kontribusi yang hampir seimbang. Artinya, kedua produk ini juga cukup digemari dan menjadi pilihan umum konsumen.
#
# 3. Sunscreen dan Face Cream & Lotion berada di posisi lebih rendah (18–19%)
#
#     Meskipun berada di bawah kategori lainnya, persentase ini masih menunjukkan tingkat rekomendasi yang signifikan. Produk-produk ini tetap penting, namun tidak sepopuler Toner, Face Wash, atau Sheet Mask dalam rekomendasi pelanggan.
#
# 4. Perbedaannya tidak terlalu jauh antar kategori
#
#     Rentang persentase hanya sekitar 18%–22%, yang berarti semua kategori ini sebenarnya sama-sama populer, hanya saja Toner sedikit lebih unggul.

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas: Menganalisis penyebaran nilai rating rata-rata pada kolom average_rating
#
# Tujuan: Melihat bagaimana distribusi rating produk dan mendeteksi kecondongan (skewness) dalam data rating.
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['average_rating'], bins=20, kde=True)
plt.title('Distribusi Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Dari hasil visualisasi tersebut dapat disimpulkan:
#
# Distribusi Average Rating menunjukkan bahwa performa produk di Sociolla cenderung sangat baik, karena mayoritas berada di rating 4.5–5.0. Meski begitu, tetap ada sejumlah kecil produk yang memiliki rating sangat rendah, namun jumlahnya tidak signifikan.

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas: Menganalisis hubungan antara nilai rating rata-rata produk (average_rating) dengan jumlah rekomendasi pelanggan (total_recommended_count).
#
# Tujuan: Melihat apakah rating tinggi berhubungan dengan banyaknya orang yang merekomendasikan produk.
#
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['average_rating', 'total_recommended_count']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Hubungan antara Average Rating dan Total Recommended Count')
plt.show()

# %% [markdown]
# Dari hasil visualisasi tersebut dapat disimpulkan:
#
# Heatmap tersebut menunjukkan bahwa hubungan antara average_rating dan total_recommended_count sangat lemah, dengan korelasi hanya sekitar 0.12.
#
# Artinya, meskipun sebuah produk memiliki rating yang tinggi, hal itu tidak selalu berarti produk tersebut banyak direkomendasikan oleh pelanggan. Jumlah rekomendasi tampaknya dipengaruhi oleh faktor lain seperti popularitas brand, jumlah pengguna yang aktif memberikan review, atau tingkat penggunaan produk, sehingga rating tinggi tidak otomatis berbanding lurus dengan banyaknya rekomendasi.
